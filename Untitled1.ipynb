# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/KDD_Train.csv')
df
# Out:
#        duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data   SF        491          0     0
# 1             0           udp     other   SF        146          0     0
# 2             0           tcp   private   S0          0          0     0
# 3             0           tcp      http   SF        232       8153     0
# 4             0           tcp      http   SF        199        420     0
# ...         ...           ...       ...  ...        ...        ...   ...
# 18529         0           tcp      smtp   SF        743        333     0
# 18530         0           udp  domain_u   SF         44         74     0
# 18531         0           tcp      nntp   S0          0          0     0
# 18532         5           tcp    telnet   SF        109       5573     0
# 18533         0           tcp      http  REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                25.0
# 1                   0       0    0  ...                 1.0
# 2                   0       0    0  ...                26.0
# 3                   0       0    0  ...               255.0
# 4                   0       0    0  ...               255.0
# ...               ...     ...  ...  ...                 ...
# 18529               0       0    0  ...               131.0
# 18530               0       0    0  ...               254.0
# 18531               0       0    0  ...                20.0
# 18532               0       0    0  ...                 3.0
# 18533               0       0    0  ...                 NaN
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 18529                    0.55                    0.03
# 18530                    1.00                    0.01
# 18531                    0.08                    0.07
# 18532                    0.02                    0.04
# 18533                     NaN                     NaN
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 18529                         0.00                         0.02
# 18530                         0.00                         0.00
# 18531                         0.00                         0.00
# 18532                         0.01                         0.00
# 18533                          NaN                          NaN
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 18529                  0.00                      0.00                  0.00
# 18530                  0.00                      0.00                  0.00
# 18531                  1.00                      1.00                  0.00
# 18532                  0.01                      0.00                  0.00
# 18533                   NaN                       NaN                   NaN
#
#        dst_host_srv_rerror_rate    class
# 0                          0.00   normal
# 1                          0.00   normal
# 2                          0.00  anomaly
# 3                          0.01   normal
# 4                          0.00   normal
# ...                         ...      ...
# 18529                      0.00   normal
# 18530                      0.00   normal
# 18531                      0.00  anomaly
# 18532                      0.00   normal
# 18533                       NaN      NaN
#
# [18534 rows x 42 columns]

# %%
df.replace(('normal','anomaly'), (0,1), inplace=True)

# %%
for column_name in df.columns:
    if df[column_name].dtypes=='object':
        a =df[column_name].unique()
        a=len(a)
        print(column_name+ " has "+ str(a) +" unique values. ")
# Out:
# protocol_type has 3 unique values.
# service has 66 unique values.
# flag has 11 unique values.

# %%
df['protocol_type'].head(5)
# Out:
# 0    tcp
# 1    udp
# 2    tcp
# 3    tcp
# 4    tcp
# Name: protocol_type, dtype: object

# %%
df['protocol_type'].value_counts()
# Out:
# protocol_type
# tcp     15115
# udp      2214
# icmp     1205
# Name: count, dtype: int64

# %%
print(pd.get_dummies(df['protocol_type']).head(5))
# Out:
#     icmp    tcp    udp
# 0  False   True  False
# 1  False  False   True
# 2  False   True  False
# 3  False   True  False
# 4  False   True  False

# %%
def dummy_df(df):
    todummy_list = ['protocol_type', 'service','flag']
    for x in todummy_list:
        dummies=pd.get_dummies(df[x],dummy_na=False)
        df = df.drop(x,axis= 1)
        df = pd.concat([df, dummies], axis=1)
    return df

# %%
df = dummy_df(df)
df.head(5)
# Out:
#    duration  src_bytes  dst_bytes  land  wrong_fragment  urgent  hot  \
# 0         0        491          0     0               0       0    0
# 1         0        146          0     0               0       0    0
# 2         0          0          0     0               0       0    0
# 3         0        232       8153     0               0       0    0
# 4         0        199        420     0               0       0    0
#
#    num_failed_logins  logged_in  num_compromised  ...    REJ   RSTO  RSTOS0  \
# 0                  0          0                0  ...  False  False   False
# 1                  0          0                0  ...  False  False   False
# 2                  0          0                0  ...  False  False   False
# 3                  0          1                0  ...  False  False   False
# 4                  0          1                0  ...  False  False   False
#
#     RSTR     S0     S1     S2     S3     SF     SH
# 0  False  False  False  False  False   True  False
# 1  False  False  False  False  False   True  False
# 2  False   True  False  False  False  False  False
# 3  False  False  False  False  False   True  False
# 4  False  False  False  False  False   True  False
#
# [5 rows x 119 columns]

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# dst_host_srv_rerror_rate    1
# dst_host_srv_count          1
# serror_rate                 1
# srv_serror_rate             1
# rerror_rate                 1
#                            ..
# efs                         0
# ecr_i                       0
# eco_i                       0
# echo                        0
# SH                          0
# Length: 119, dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imr = SimpleImputer(missing_values=np.nan, strategy='median')
imr.fit(df)
df = pd.DataFrame(data=imr.transform(df), columns=df.columns)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# duration                       0
# name                           0
# printer                        0
# pop_3                          0
# pop_2                          0
#                               ..
# dst_host_srv_serror_rate       0
# dst_host_serror_rate           0
# dst_host_srv_diff_host_rate    0
# dst_host_same_src_port_rate    0
# SH                             0
# Length: 119, dtype: int64

# %%
x = df.drop ('class',axis= 1)
y = df['class']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1, stratify=y)

# %%
print('Labels count in y:', np.bincount(y))
print('Labels count in y_train:', np.bincount(y_train))
print('Labels count in y_test:', np.bincount(y_test))
# Out:
# Labels count in y: [9887 8647]
# Labels count in y_train: [6920 6053]
# Labels count in y_test: [2967 2594]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(eta0=0.1, random_state=1)
ppn.fit(x_train_std, y_train)
# Out:
# Perceptron(eta0=0.1, random_state=1)

# %%
y_pred = ppn.predict(x_test_std)
print('Misclassified examples: %d' % (y_test != y_pred).sum())
# Out:
# Misclassified examples: 247

# %%
from sklearn.metrics import accuracy_score

print('Accuracy: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.956

# %%
print('Accuracy: %.3f' % ppn.score(x_test_std, y_test))
# Out:
# Accuracy: 0.956

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt


def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0],
                    y=X[y == cl, 1],
                    alpha=0.8,
                    c=colors[idx],
                    marker=markers[idx],
                    label=cl,
                    edgecolor='black')

    # highlight test examples
    if test_idx:
        # plot all examples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100,
                    label='test set')

# %%
# !pip install mlxtend --upgrade # Upgrade mlxtend to the latest version

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder # Import LabelEncoder
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions # Import plot_decision_regions

df = pd.read_csv('/content/KDD_Train.csv')
# Assuming the target variable is in a column called 'target'
x = df.drop ('class',axis= 1)
y = df['class']

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate over each column in x
for col in x.columns:
    # Check if the column has object dtype
    if x[col].dtype == 'object':
        # Fit and transform the column using LabelEncoder
        x[col] = label_encoder.fit_transform(x[col])

# Split the preprocessed dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

tree_model = DecisionTreeClassifier(criterion='gini',
                                    max_depth=4,
                                    random_state=1)
tree_model.fit(X_train, y_train)
import numpy as np


X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))

plot_decision_regions(X_combined, y_combined,
                      clf=tree_model, # Use clf instead of classifier
                      test_idx=range(105, 150))

plt.xlabel('class')
plt.ylabel('class label')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-950d292d8e4f> in <cell line: 6>()
#       4                                     max_depth=4,
#       5                                     random_state=1)
# ----> 6 tree_model.fit(X_train, y_train)
#       7
#       8 X_combined = np.vstack((X_train, X_test))
#
# NameError: name 'X_train' is not defined

# %%
from sklearn import tree

tree.plot_tree(tree_model)
#plt.savefig('images/03_21_1.pdf')
plt.show()

# %%
# !pip3 install pydotplus

# %%
# !conda install python-graphviz

# %%
# !pip install graphviz

# %%
# !pip3 install pydotplus

# %%
from pydotplus import graph_from_dot_data
from sklearn.tree import export_graphviz

dot_data = export_graphviz(tree_model,
                           filled=True,
                           rounded=True,
                           class_names=['icmp',
                                        'tcp',
                                        'udp'],
                           feature_names=['class label',
                                          'class'],
                           out_file=None)
graph = graph_from_dot_data(dot_data)
graph.write_png('tree.png')

# %%
Image(filename='images/03_23.png', width=400)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5,
                           p=2,
                           metric='minkowski')
knn.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,
                      classifier=knn, test_idx=range(105, 150))

plt.xlabel(' [standardized]')
plt.ylabel(' [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_24.png', dpi=300)
plt.show()
